# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir(r'C:\Users\QJ\Desktop\奥运健儿那些事儿\analysis_data')
# 创建工作路径

import warnings
warnings.filterwarnings('ignore') 
# 不发出警告

df = pd.read_excel('奥运运动员数据.xlsx',sheetname=1,header=0)
data2 = df[['event','name','height','weight']]
data2.dropna(inplace = True)
# 去掉缺失值

data2['BMI'] = data2['weight']/(data2['height']/100)**2   # **2 → 平方
data2['BMI_range'] = pd.cut(data2['BMI'],
                            [0,18.5,24,28,50],            # 划分区间
                            labels=["Thin", "Normal", "Strong",'ExtremelyStrong'])   # 区间标签   
# 计算运动员BMI指数，并整理出BMI区间值
# 这里根据运动员特点，设置为四挡：低于18.5纤瘦，18.5-23.9适中，24-27强壮，28-32极壮
# pandas.cut → 划分区间，并返回shape相同的dataframe

sns.set_style("ticks")
# 图表风格设置

plt.figure(figsize = (8,4))  # 设置作图大小
sns.violinplot(x="event", y="BMI", data=data2,   # 设置数据
               scale = 'count',      # 宽度以样本数量来显示 → 数据样本越多，小提琴图越宽
               palette = "hls",      # 设置调色盘      
               inner = "quartile")   # 内部显示为分位数
# 绘制小提琴图

sns.swarmplot(x="event", y="BMI", data=data2, color="w", alpha=.8,s=2)
# 绘制内部散点图

plt.grid(linestyle = '--')     # 添加网格线
plt.title("Athlete's BMI")  # 添加图表名
# 图表其他内容

plt.savefig('pic2.png',dpi=400)
# 图表导出
# Out:
# C:\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             event name  height  weight        BMI        BMI_range
# 22  weightlifting   杨哲     187   105.0  30.026595  ExtremelyStrong
# 27  weightlifting  孟苏平     173   115.0  38.424271  ExtremelyStrong
# 36  weightlifting  周璐璐     175   130.0  42.448980  ExtremelyStrong
